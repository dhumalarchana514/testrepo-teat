# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Archana S** <BR> Data Analyst

# %% [markdown]
# _I am interested in data science because i like to explore hidden relation in big data sets._

# %% [markdown]
# ### The code in cell 5 is a simple addition of 1+1 which results 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# # Table
# | Name | Vorname | Alter |
# | --- | --- | --- |
# | S | Archana | 32 |
# # Numbered List
# <ol>
#   <p>Tool List.</p>
#   <li>Jupyter Notebooks.</li>
#   <li>RStudio.</li>
# </ol>
# # Hyper Link <BR>
# https://www.coursera.org <BR>
#     <a href="https://www.coursera.org">Coursera</a>
#
# # Blocked Code
# >This is a Blocked Code line
# >
# >This is another Blocked Code line <BR>
